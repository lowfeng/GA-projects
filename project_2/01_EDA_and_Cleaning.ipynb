# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2

# %% [markdown]
# ## Contents:
# - [Problem Statement](#Problem-Statement)
# - [Data Source](#Data-Source)
# - [Outside Research](#Outside-Research)
# - [Data Dictionary](#Data-Dictionary)
# - [Import Libraries & Datasets](#Import-Libraries-&-Datasets)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)

# %% [markdown]
# ## Problem Statement
#
# A real estate company is looking to sell their properties in the Ames, Iowa area and make a return on their investment. Hence, they are keen to know the valuation of their properties. They are also keen to know which housing features can contribute the most to the valuation, so that they can upgrade properties with a low ROI and appreciate its value.

# %% [markdown]
# ## Data Source

# %% [markdown]
# * [`train.csv`](./datasets/train.csv):  this data contains all of the training data for your model
# * [`new_test.csv`](./datasets/new_test.csv): this data contains the test data for your model. You will feed this data into your regression model to make predictions.
# * [`sample_sub_reg.csv`](./datasets/sample_sub_reg.csv): An example of a correctly formatted submission for this challenge (with a random number provided as predictions for SalePrice. Please ensure that your submission to Kaggle matches this format.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# **The Ames Housing Data**
#
# * There are 80 variables focused on the quality and quantity of the many physical attributes of the property, with 2 additional observation identifiers. Most of the variables are information that a real estate company would want to know about a potential property.
#
#     * **20 continuous variables that relate to various area dimensions for each obseration**
#         * Area measurements on the basement / main living area / porches are broken down into individual categories based on quality and type
#         * Opportunity to use methods to combine the variables
#     * **14 discrete variables to quantify the number of items within the house**
#         * Number of kitchens / bedrooms / bathrooms located in the basement and above ground (grade).
#         * Also included are the garage capacity and dates
#     * **46 categorical variables, of which, 23 nominal & 23 ordinal**
#         * Range from 2 to 28 classes with smallest being the street and largest being the neighbourhood.
#         * Nominal variables identify various types of dwellings / garages / materials / environmental conditions
#         * Ordinal variables rate items in the property
#     * **2 observation identifiers**
#         * The PID variable can be used in conjunction with the [Assessor's Office](http://www.cityofames.org/assessor/) or [Beacon](http://beacon.schneidercorp.com/) websites to directly view the records of a particular observation
#
#     * **Others**
#         * The neighbourhood variable can be used to model the location effect, and is of relevance when using the [map](http://www.amstat.org/publications/jse/v19n3/decock/AmesResidential.pdf)

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# <details> <summary> Data contains information from the Ames Assessor’s Office used in computing assessed values for individual residential properties sold in Ames, IA from 2006 to 2010
# </summary>
#
# |Feature|Dataset|Type|Description|
# |:--|:-:|:-:|:--|
# |Order|Discrete|int64|Observation number|
# |PID|Nominal|int64|Parcel identification number - can be used with city web site for parcel review|
# |MS SubClass|Nominal|int64|Identifies the type of dwelling involved in the sale|
# |MS Zoning|Nominal|object|Identifies the general zoning classification of the sale|
# |Lot Frontage|Continuous|float64|Linear feet of street connected to property|
# |Lot Area|Continuous|int64|Lot size in square feet|
# |Street|Nominal|object|Type of road access to property|
# |Alley|Nominal|object|Type of alley access to property|
# |Lot Shape|Ordinal|object|General shape of property|
# |Land Contour|Nominal|object|Flatness of the property|
# |Utilities|Ordinal|object|Type of utilities available|
# |Lot Config|Nominal|object|Lot configuration|
# |Land Slope|Ordinal|object|Slope of property|
# |Neighborhood|Nominal|object|Physical locations within Ames city limits (map available)|
# |Condition 1|Nominal|object|Proximity to various conditions|
# |Condition 2|Nominal|object|Proximity to various conditions (if more than one is present)|
# |Bldg Type|Nominal|object|Type of dwelling|
# |House Style|Nominal|object|Style of dwelling|
# |Overall Qual|Ordinal|int64|Rates the overall material and finish of the house|
# |Overall Cond|Ordinal|int64|Rates the overall condition of the house|
# |Year Built|Discrete|int64|Original construction date|
# |Year Remod/Add|Discrete|int64|Remodel date (same as construction date if no remodeling or additions)|
# |Roof Style|Nominal|object|Type of roof|
# |Roof Matl|Nominal|object|Roof material|
# |Exterior 1st|Nominal|object|Exterior covering on house|
# |Exterior 2nd|Nominal)|object|Exterior covering on house (if more than one material)|
# |Mas Vnr Type|Nominal|object|Masonry veneer type|
# |Mas Vnr Area|Continuous|float64|Masonry veneer area in square feet|
# |Exter Qual|Ordinal|object|Evaluates the quality of the material on the exterior|
# |Exter Cond|Ordinal|object|Evaluates the present condition of the material on the exterior|
# |Foundation|Nominal|object|Type of foundation|
# |Bsmt Qual|Ordinal|object|Evaluates the height of the basement|
# |Bsmt Cond|Ordinal|object|Evaluates the general condition of the basement|
# |Bsmt Exposure|Ordinal|object|Refers to walkout or garden level walls|
# |BsmtFin Type 1|Ordinal|object|Rating of basement finished area|
# |BsmtFin SF 1|Continuous|float64|Type 1 finished square feet|
# |BsmtFinType 2|Ordinal|object|Rating of basement finished area (if multiple types)|
# |BsmtFin SF 2|Continuous|float64|Type 2 finished square feet|
# |Bsmt Unf SF|Continuous)|float64|Unfinished square feet of basement area|
# |Total Bsmt SF|Continuous|float64|Total square feet of basement area|
# |Heating|Nominal|object|Type of heating|
# |HeatingQC|Ordinal|object|Heating quality and condition|
# |Central Air|Nominal|object|Central air conditioning|
# |Electrical|Ordinal|object|Electrical system|
# |1st Flr SF|Continuous|int64|First Floor square feet|
# |2nd Flr SF|Continuous|int64|Second floor square feet|
# |Low Qual Fin SF|Continuous|int64|Low quality finished square feet (all floors)|
# |Gr Liv Area|Continuous|int64|Above grade (ground) living area square feet|
# |Bsmt Full Bath|Discrete|float64|Basement full bathrooms|
# |Bsmt Half Bath|Discrete|float64|Basement half bathrooms|
# |Full Bath|Discrete|int64|Full bathrooms above grade|
# |Half Bath|Discrete|int64|Half baths above grade|
# |Bedroom|Discrete|int64|Bedrooms above grade (does NOT include basement bedrooms)|
# |Kitchen|Discrete|int64|Kitchens above grade|
# |KitchenQual|Ordinal|object|Kitchen quality|
# |TotRms AbvGrd|Discrete|int64|Total rooms above grade (does not include bathrooms)|
# |Functional|Ordinal|object|Home functionality (Assume typical unless deductions are warranted)|
# |Fireplaces|Discrete|int64|Number of fireplaces|
# |FireplaceQu|Ordinal|object|Fireplace quality|
# |Garage Type|Nominal|object|Garage location|
# |Garage Yr Blt|Discrete|int64|Year garage was built|
# |Garage Finish|Ordinal|object|Interior finish of the garage|
# |Garage Cars|Discrete|int64|Size of garage in car capacity|
# |Garage Area|Continuous|float64|Size of garage in square feet|
# |Garage Qual|Ordinal|object|Garage quality|
# |Garage Cond|Ordinal|object|Garage condition|
# |Paved Drive|Ordinal|object|Paved driveway|
# |Wood Deck SF|Continuous|float64|Wood deck area in square feet|
# |Open Porch SF|Continuous|float64|Open porch area in square feet|
# |Enclosed Porch|Continuous|float64|Enclosed porch area in square feet|
# |3-Ssn Porch|Continuous|float64|Three season porch area in square feet|
# |Screen Porch|Continuous|float64|Screen porch area in square feet|
# |Pool Area|Continuous|float64|Pool area in square feet|
# |Pool QC|Ordinal|object|Pool quality|
# |Fence|Ordinal|object|Fence quality|
# |Misc Feature|Nominal|object|Miscellaneous feature not covered in other categories|
# |Misc Val|Continuous|float64|$Value of miscellaneous feature|
# |Mo Sold|Discrete|int64|Month Sold (MM)|
# |Yr Sold|Discrete)|int64|Year Sold (YYYY)|
# |Sale Type|Nominal|object|Type of sale|
# |Sale Condition|Nominal|object|Condition of sale|
# |SalePrice|Continuous|float64|Sale price|

# %% [markdown]
# ## Import Libraries & Datasets

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split, cross_val_score

# %matplotlib inline

# Display max 500 columns
pd.set_option('display.max_columns', 500)

# Read datasets
train = pd.read_csv('./datasets/train.csv')
test = pd.read_csv('./datasets/new_test.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
# ---
#
# Before cleaning the data, I analyzed the dataset using some exploratory functions. This helped break down the problem and identify what my workflow should look like, and to ultimately have the best set of data to fit the model.

# %% [markdown]
# ### Check Data Shape

# %%
# Observe the shape of the train and test data
print(train.shape)
print(test.shape)
# Out:
# (2051, 81)
# (879, 80)

# %% [markdown]
# - **Train data shape**
#     - There are 2048 houses and 81 variables
# - **Test data shape**
#     - There are 879 houses and 80 variables
#     - Does not have dependent variable 'SalePrice'
#
# We will first do EDA and Cleaning on the training data, and apply the same on the test data later.

# %% [markdown]
# ### Check Data Overview

# %%
#Look at the first 5 rows of the train data to get a clearer picture
train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %% [markdown]
# - The categorical (nominal & ordinal) variables will need to be mapped to numerical variables for its features to be useful in our modelling
# - At first glance, columns 'Id','PID' seems like they won't be useful for modelling as they were random numbers for indexing the house, however we'll check this out later using a scatter plot to see if a relationship with 'SalePrice' exist
# - Some features have similar names & functions which could be collinear, we'll verify their correlation using a heatmap
# - There are missing values (Nan) which will need addressing
# - Good to check for any duplicate rows
# - Overall, there seems to be too many features, which would contribute to our model being overfitted. But we will take a slow iterative approach to this to avoid omitting features potentially useful for our model

# %% [markdown]
# ### Check for Duplicates

# %%
# Check for duplicated rows based on all columns
train[train.duplicated()]
# Out:
# Empty DataFrame
# ...

# %%
# Check for duplicated rows based on ID as its a unique identifier
train[train.duplicated(['Id'])]
# Out:
# Empty DataFrame
# ...

# %%
# Check for duplicated rows based on ID as its a unique identifier
train[train.duplicated(['PID'])]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# **Remarks**
#
# - There are no rows/unique identifiers that are duplicates

# %% [markdown]
# ### Check for Outliers

# %%
#Check for outliers
train.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2051.000000  2.051000e+03  2051.000000   1721.000000    2051.000000
# mean   1474.033642  7.135900e+08    57.008776     69.055200   10065.208191
# std     843.980841  1.886918e+08    42.824223     23.260653    6742.488909
# min       1.000000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     753.500000  5.284581e+08    20.000000     58.000000    7500.000000
# 50%    1486.000000  5.354532e+08    50.000000     68.000000    9430.000000
# 75%    2198.000000  9.071801e+08    70.000000     80.000000   11513.500000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2051.000000   2051.000000  2051.000000     2051.000000   2029.000000
# mean       6.112140      5.562165  1971.708922     1984.190151     99.695909
# ...

# %% [markdown]
# * Its observed that Garage Yr Blt has a max value of 2207, which is incorrect as its beyond the dataset's range of 2006 to 2010. Hence, would like to locate all rows with values above 2010.

# %%
# Locate rows where column 'Garage Yr Blt' is incorrect, as its beyond dataset's range (2006-2010)
train.loc[
    train['Garage Yr Blt'] > 2010,
    :
]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1699  2261  916384070           20        RL          68.0      8298   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 1699   NaN       IR1          HLS    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1699       Timber        Norm        Norm      1Fam      1Story             8
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1699             5        2006            2007        Hip   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 1699      VinylSd      VinylSd          NaN           NaN         Gd
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 1699         TA      PConc        Gd        TA            Av            GLQ
#
# ...

# %% [markdown]
# * There is only one row which has 'Garage Yr Blt' value of 2207.
# * Based on observation, we can see that
#     * 'Year Built' = 2006
#     * 'Year Remod/Add' = 2007
#     * 'Year Sold' = 2007
# * I'm reluctant to drop this row as it seems to have only one incorrect value, and I will require as much data to not compromise my model
# * Hence, I deduce that 'Garage Yr Blt' = 2007 for the below reasons
#     * 2007 was the year there was remodelling and possibly the garage was added
#     * possible that 2207 was a typo

# %% [markdown]
# #### Edit row with incorrect 'Garage Yr Blt'

# %%
# Locate row with 'ID' and replace 2207 with 2007

train.loc[
    train['Id'] == 2207,
    'Garage Yr Blt'
] = 2007

# %% [markdown]
# ### Check for irrelevant data
#
# As it is clear that we want to predict the residential housing prices, looking at the data dictionary, I noticed that some properties are non-residential. Let's identify them and see how many there are and if we should retain them, as this would introduce more noise into the model

# %%
train.loc[train['MS Zoning'].isin(['A (agr)','C (all)', 'I (all)']), :]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 28    2243  911103060          190   C (all)          75.0      8250   Pave
# 103    728  902477130           30   C (all)          72.0      9392   Pave
# 183   1554  910251050           20   A (agr)          80.0     14584   Pave
# 356    943  911103050           50   C (all)         105.0      8470   Pave
# 408   1556  911102170           70   C (all)          50.0      8500   Pave
# 410    308  911204100           30   C (all)          66.0      8712   Grvl
# 426   2882  911175440          190   C (all)          50.0      9000   Pave
# 581    946  912251110           30   I (all)         109.0     21780   Grvl
# 610   2244  911128010           20   C (all)          65.0      6565   Pave
# 612   2670  902456015           50   C (all)          63.0      4761   Pave
# 635   2904  923125030           20   A (agr)         125.0     31250   Pave
# ...

# %% [markdown]
# There are 22 properties identified as non-residential, and most of them come from the IDOTRR(Iowa DOT and Rail Road) 'Neighborhood'. However, if the test data contains non-residential data, ommitting this would cause the model to be unnecessarily more bias.
#
# As such, I have decided to leave the data in here.

# %% [markdown]
# ### Check the target variable (SalePrice)

# %%
# Plot histogram to see saleprice
saleprice_values = train['SalePrice'].agg(['mean','median','std'])
print(saleprice_values)

fig, (ax1, ax2) = plt.subplots(1,2, figsize = (16, 7))

#sns.histplot(data=train, x='SalePrice', kde=True)
#plt.axvline(x=saleprice_values['median'], color='crimson', ls=':')
#plt.title('Sale Price Distribution');

sns.histplot(ax=ax1, data=train, x='SalePrice', kde=True)
ax1.axvline(x=saleprice_values['median'], color='crimson', ls=':')
ax1.set_title('Sale Price Distribution')
ax1.set_xlabel('Saleprice ($)')
ax1.set_ylabel('Number of Houses')

sns.boxplot(ax=ax2, data=train, y='SalePrice')
ax2.set_title('Boxplot of Sale Price')
ax2.set_ylabel('Saleprice ($)');
# Out:
# mean      181469.701609
# median    162500.000000
# std        79258.659352
# Name: SalePrice, dtype: float64

# %% [markdown]
# - **Distribution is right-skewed**
#     - Skewness to the right is usually a result of a lower boundary in the dataset. In this case, the lower boundary would be the minimum saleprice for a house. On the otherhand, there is no boundary on the upside as there's no maximum saleprice
#
# - **Mean & Median sale price**
#     - The mean is 181,469 and median is 162,500. As there are some outliers in the upper boundaries, I would take reference to the median as the measure of an average sale price

# %% [markdown]
# ## Data Cleaning
#
# ---
#
# It is crucial to remove or impute all missing values in our dataset to ensure that the data is sensible to use in the model. The approach taken is to first check which features have missing values, and group them according to their variable types (Categorical/Numerical), and work through with it feature by feature. This might be time consuming but necessary to understand the cause of the missing values.

# %% [markdown]
# ###  Check for missing values

# %%
# check for missing values
# Count the sum of missing values for each column

train.isnull().sum().sort_values(ascending=False)[:27]
# Out:
# Pool QC           2042
# Misc Feature      1986
# Alley             1911
# Fence             1651
# Fireplace Qu      1000
# Lot Frontage       330
# Garage Finish      114
# Garage Qual        114
# Garage Yr Blt      114
# Garage Cond        114
# Garage Type        113
# Bsmt Exposure       58
# BsmtFin Type 2      56
# BsmtFin Type 1      55
# Bsmt Cond           55
# Bsmt Qual           55
# Mas Vnr Area        22
# Mas Vnr Type        22
# Bsmt Half Bath       2
# Bsmt Full Bath       2
# Garage Area          1
# Total Bsmt SF        1
# Bsmt Unf SF          1
# BsmtFin SF 2         1
# BsmtFin SF 1         1
# Garage Cars          1
# Mo Sold              0
# dtype: int64

# %% [markdown]
# **Remarks**
# - There are 26 columns with missing data
# - Referring to the [Data Dictionary](#Data-Dictionary), its observed that all missing values are represented by all variable types (Categorical & Numerical)
# - Data will be checked & cleaned in order of
#     - **Variable Type** (If more than 2 missing values in column)
#         - Ordinal
#         - Nominal
#         - Continous
#         - Discrete
#
#     - **Others** (If 2 or less missing values in column)
#         5. Others

# %% [markdown]
# ### Ordinal Variables
#  1. Pool QC
#  2. Fence
#  3. Fireplace Qu
#  4. Garage Finish
#  5. Garage Qual
#  6. Garage Cond
#  7. Bsmt Exposure
#  8. BsmtFin Type 2
#  9. BsmtFin Type 1
#  10. Bsmt Cond
#  11. Bsmt Qual

# %%
# Missing values for Pool QC
print(train['Pool QC'].unique())
train.loc[
    train['Pool QC'].isnull(),
    ['Pool Area','Pool QC']
]
# Out:
# [nan 'Fa' 'Gd' 'Ex' 'TA']
#       Pool Area Pool QC
# 0             0     NaN
# 1             0     NaN
# 2             0     NaN
# 3             0     NaN
# 4             0     NaN
# ...         ...     ...
# 2046          0     NaN
# 2047          0     NaN
# 2048          0     NaN
# 2049          0     NaN
# 2050          0     NaN
#
# [2042 rows x 2 columns]

# %% [markdown]
# - **Pool QC**
#     - The missing values represents (no pool) as the corresponding 'Pool Area' is 0
#     - [nan 'Fa' 'Gd' 'Ex' 'TA']
#     - Hence Nan will be replaced with 'NA'

# %%
# Check the unique values
print(train['Fence'].unique())

# Missing values for Fence
train.loc[
    train['Fence'].isnull(),
    :
]
# Out:
# [nan 'MnPrv' 'GdPrv' 'GdWo' 'MnWw']
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
# ...

# %% [markdown]
# - **Fence**
#     - The missing values represents (no fence) as its the only category unaccounted for
#     - [nan 'MnPrv' 'GdPrv' 'GdWo' 'MnWw']
#     - Hence Nan will be replaced with 'NA'

# %%
# Check the unique values
print(train['Fireplace Qu'].unique())

# Missing values for Fence
train.loc[
    train['Fireplace Qu'].isnull(),
    :
]
# Out:
# [nan 'TA' 'Gd' 'Po' 'Ex' 'Fa']
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# 6     2827  908186070          180        RM          35.0      3675   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2034  2775  907175060           20        RL          79.0      9236   Pave
# 2038  1892  534401200           80        RL          80.0      9200   Pave
# 2039  2288  923228220          160        RM          21.0      1495   Pave
# 2044  1140  531382090           60        RL          65.0      8453   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
#
# ...

# %% [markdown]
# - **Fireplace Qu**
#     - The missing values represents (no fireplace) as its the only category unaccounted for
#     - [nan 'TA' 'Gd' 'Po' 'Ex' 'Fa']
#     - Hence Nan will be replaced with 'NA'

# %%
# Check the unique values
print(train['Garage Finish'].unique())
print(train['Garage Qual'].unique())
print(train['Garage Cond'].unique())

# Missing values for Fence
train.loc[
    train['Garage Finish'].isnull(),
    ['Garage Type',
     'Garage Yr Blt',
     'Garage Finish',
     'Garage Cars',
     'Garage Area',
     'Garage Qual',
     'Garage Cond',
    ]
]
# Out:
# ['RFn' 'Unf' 'Fin' nan]
# ['TA' 'Fa' nan 'Gd' 'Ex' 'Po']
# ['TA' 'Fa' nan 'Po' 'Gd' 'Ex']
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 28           NaN            NaN           NaN          0.0          0.0
# 53           NaN            NaN           NaN          0.0          0.0
# 65           NaN            NaN           NaN          0.0          0.0
# 79           NaN            NaN           NaN          0.0          0.0
# 101          NaN            NaN           NaN          0.0          0.0
# ...          ...            ...           ...          ...          ...
# 1991         NaN            NaN           NaN          0.0          0.0
# 2010         NaN            NaN           NaN          0.0          0.0
# 2027         NaN            NaN           NaN          0.0          0.0
# 2039         NaN            NaN           NaN          0.0          0.0
# 2042         NaN            NaN           NaN          0.0          0.0
#
# ...

# %% [markdown]
# - **Garage Finish / Garage Qual / Garage Cond**
#     - The missing values represents (no garage) as all the corresponding 'Garage Area' is 0
#     - ['RFn' 'Unf' 'Fin' nan]
#     - ['TA' 'Fa' nan 'Gd' 'Ex' 'Po']
#     - ['TA' 'Fa' nan 'Po' 'Gd' 'Ex']
#     - Hence Nan will be replaced with 'NA'

# %%
# Check the unique values
print(train['Bsmt Exposure'].unique())

# Missing values for Bsmt Exposure
train.loc[
    train['Bsmt Exposure'].isnull(),
    ['Bsmt Qual',
    'Bsmt Cond',
    'Bsmt Exposure',
    'BsmtFin Type 1',
    'BsmtFin Type 2',
    'BsmtFin SF 1',
    'BsmtFin SF 2',
    'Bsmt Unf SF',
    'Total Bsmt SF',
    'Bsmt Full Bath',
    'Bsmt Half Bath'
    ]
]
# Out:
# ['No' 'Gd' 'Av' nan 'Mn']
#      Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin Type 2  \
# 12         NaN       NaN           NaN            NaN            NaN
# 93         NaN       NaN           NaN            NaN            NaN
# 114        NaN       NaN           NaN            NaN            NaN
# 146        NaN       NaN           NaN            NaN            NaN
# 183        NaN       NaN           NaN            NaN            NaN
# 240        NaN       NaN           NaN            NaN            NaN
# 249        NaN       NaN           NaN            NaN            NaN
# 256        NaN       NaN           NaN            NaN            NaN
# 390        NaN       NaN           NaN            NaN            NaN
# 437        NaN       NaN           NaN            NaN            NaN
# 485        NaN       NaN           NaN            NaN            NaN
# 499        NaN       NaN           NaN            NaN            NaN
# ...

# %% [markdown]
# - **Bsmt Exposure**
#     - The missing values represents (no basement) as all the corresponding 'Total Bsmt SF' is 0
#     - Index 1456/1547/1997 have unfinished basements
#     - ['No' 'Gd' 'Av' nan 'Mn']
#     - Hence Nan will be replaced with 'NA'

# %%
# Check the unique values
print(train['BsmtFin Type 2'].unique())
print(train['BsmtFin Type 1'].unique())

# Missing values for BsmtFin Type 2 & BsmtFin Type 1
train.loc[
    (train['BsmtFin Type 2'].isnull()) | (train['BsmtFin Type 2'].isnull()),
    ['Id',
    'Bsmt Qual',
    'Bsmt Cond',
    'Bsmt Exposure',
    'BsmtFin Type 1',
    'BsmtFin Type 2',
    'BsmtFin SF 1',
    'BsmtFin SF 2',
    'Bsmt Unf SF',
    'Total Bsmt SF',
    'Bsmt Full Bath',
    'Bsmt Half Bath'
    ]
]
# Out:
# ['Unf' 'Rec' nan 'BLQ' 'GLQ' 'LwQ' 'ALQ']
# ['GLQ' 'Unf' 'ALQ' 'Rec' nan 'BLQ' 'LwQ']
#         Id Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin Type 2  \
# 12     807       NaN       NaN           NaN            NaN            NaN
# 93     811       NaN       NaN           NaN            NaN            NaN
# 114    781       NaN       NaN           NaN            NaN            NaN
# 146    888       NaN       NaN           NaN            NaN            NaN
# 183   1554       NaN       NaN           NaN            NaN            NaN
# 240   2740       NaN       NaN           NaN            NaN            NaN
# 249   2242       NaN       NaN           NaN            NaN            NaN
# 256   2745       NaN       NaN           NaN            NaN            NaN
# 390     84       NaN       NaN           NaN            NaN            NaN
# 437   1501       NaN       NaN           NaN            NaN            NaN
# ...

# %% [markdown]
# - **Bsmt FinType1 / Bsmt Fin Type2**
#     - The missing values represents (no basement) as all the corresponding 'Total Bsmt SF' is 0
#     - ['Unf' 'Rec' nan 'BLQ' 'GLQ' 'LwQ' 'ALQ']
#     - ['GLQ' 'Unf' 'ALQ' 'Rec' nan 'BLQ' 'LwQ']
#     - Hence Nan will be replaced with 'NA'

# %%
# Check the unique values
print(train['Bsmt Cond'].unique())
print(train['Bsmt Qual'].unique())

# Missing values for BsmtFin Cond & BsmtFin Qual
train.loc[
    (train['Bsmt Cond'].isnull()) | (train['Bsmt Qual'].isnull()),
    ['Id',
    'Bsmt Qual',
    'Bsmt Cond',
    'Bsmt Exposure',
    'BsmtFin Type 1',
    'BsmtFin Type 2',
    'BsmtFin SF 1',
    'BsmtFin SF 2',
    'Bsmt Unf SF',
    'Total Bsmt SF',
    'Bsmt Full Bath',
    'Bsmt Half Bath'
    ]
]
# Out:
# ['TA' 'Gd' nan 'Fa' 'Po' 'Ex']
# ['TA' 'Gd' 'Fa' nan 'Ex' 'Po']
#         Id Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1 BsmtFin Type 2  \
# 12     807       NaN       NaN           NaN            NaN            NaN
# 93     811       NaN       NaN           NaN            NaN            NaN
# 114    781       NaN       NaN           NaN            NaN            NaN
# 146    888       NaN       NaN           NaN            NaN            NaN
# 183   1554       NaN       NaN           NaN            NaN            NaN
# 240   2740       NaN       NaN           NaN            NaN            NaN
# 249   2242       NaN       NaN           NaN            NaN            NaN
# 256   2745       NaN       NaN           NaN            NaN            NaN
# 390     84       NaN       NaN           NaN            NaN            NaN
# 437   1501       NaN       NaN           NaN            NaN            NaN
# 485    155       NaN       NaN           NaN            NaN            NaN
# ...

# %% [markdown]
# - **Bsmt Cond /Bsmt Qual**
#     - The missing values represents (no basement) as all the corresponding 'Total Bsmt SF' is 0
#     - ['TA' 'Gd' nan 'Fa' 'Po' 'Ex']
#     - ['TA' 'Gd' 'Fa' nan 'Ex' 'Po']
#     - Hence Nan will be replaced with 'NA'

# %% [markdown]
# #### Convert Ordinal Variables

# %%
# Convert all nan to 'NA' in Ordinal Variables
ordinal_columns = [
        'Pool QC',
        'Fence',
        'Fireplace Qu',
        'Garage Finish',
        'Garage Qual',
        'Garage Cond',
        'Bsmt Exposure',
        'BsmtFin Type 2',
        'BsmtFin Type 1',
        'Bsmt Cond',
        'Bsmt Qual'
]

# Using list comprehension, for each column, replace nan with 'NA'
[train[x].replace(np.nan, 'NA_', inplace=True) for x in ordinal_columns]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# **Remarks**
#
# * As all the missing values in the ordinal variables can be replaced by 'NA', we used a list comprehension to iterate through the columns to replace the Nan

# %% [markdown]
# ### Nominal Variables
#
# 1. Misc Feature
# 2. Alley
# 3. Garage Type
# 4. Mas Vnr Type

# %%
# Check the unique values
print(train['Misc Feature'].unique())

# Missing values for Misc Feature
train.loc[
    train['Misc Feature'].isnull(),
    :
]
# Out:
# [nan 'Shed' 'TenC' 'Gar2' 'Othr' 'Elev']
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
# ...

# %% [markdown]
# - **Misc Feature**
#     - The missing values represents (no miscelleanous features) as its the only category unaccounted for in the data description
#     - [nan 'Shed' 'TenC' 'Gar2' 'Othr' 'Elev']
#     - replace Nan with 'NA'

# %%
# Check the unique values
print(train['Alley'].unique())

# Missing values for Alley
train.loc[
    train['Alley'].isnull(),
    :
]
# Out:
# [nan 'Pave' 'Grvl']
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
# ...

# %% [markdown]
# - **Alley**
#     - The missing values represents (no alley) as its the only category unaccounted for in the data description
#     - [nan 'Pave' 'Grvl']
#     - replace Nan with 'NA'

# %%
# Check the unique values
print(train['Garage Type'].unique())

# Missing values for Garage Type
train.loc[
    train['Garage Type'].isnull(),
    ['Garage Type','Garage Yr Blt','Garage Finish','Garage Cars','Garage Area','Garage Qual','Garage Cond']
]
# Out:
# ['Attchd' 'Detchd' 'BuiltIn' 'Basment' nan '2Types' 'CarPort']
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 28           NaN            NaN           NA_          0.0          0.0
# 53           NaN            NaN           NA_          0.0          0.0
# 65           NaN            NaN           NA_          0.0          0.0
# 79           NaN            NaN           NA_          0.0          0.0
# 101          NaN            NaN           NA_          0.0          0.0
# ...          ...            ...           ...          ...          ...
# 1991         NaN            NaN           NA_          0.0          0.0
# 2010         NaN            NaN           NA_          0.0          0.0
# 2027         NaN            NaN           NA_          0.0          0.0
# 2039         NaN            NaN           NA_          0.0          0.0
# 2042         NaN            NaN           NA_          0.0          0.0
#
#      Garage Qual Garage Cond
# ...

# %% [markdown]
# - **Garage Type**
#     - The missing value represents (No Garage) as all the corresponding 'Garage Type' are 0
#     - ['2Types', 'Attchd', 'Basement', 'BuiltIn', 'CarPort', 'Detchd', Nan]
#     - Hence Nan will be replaced with 'NA'

# %%
# Check the unique values
print(train['Mas Vnr Type'].unique())


# Missing values for Mas Vnr Type
train.loc[
    train['Mas Vnr Type'].isnull(),
    ['Mas Vnr Type', 'Mas Vnr Area']
]
# Out:
# ['BrkFace' 'None' nan 'Stone' 'BrkCmn']
#      Mas Vnr Type  Mas Vnr Area
# 22            NaN           NaN
# 41            NaN           NaN
# 86            NaN           NaN
# 212           NaN           NaN
# 276           NaN           NaN
# 338           NaN           NaN
# 431           NaN           NaN
# 451           NaN           NaN
# 591           NaN           NaN
# 844           NaN           NaN
# 913           NaN           NaN
# 939           NaN           NaN
# 1025          NaN           NaN
# 1244          NaN           NaN
# 1306          NaN           NaN
# 1430          NaN           NaN
# 1434          NaN           NaN
# 1606          NaN           NaN
# 1699          NaN           NaN
# 1815          NaN           NaN
# 1820          NaN           NaN
# 1941          NaN           NaN

# %% [markdown]
# - **Mas Vnr Type**
#     - The missing value represents (None) as all the corresponding 'Mas Vnr Area' are 0
#     - ['BrkFace' 'None' nan 'Stone' 'BrkCmn']
#     - Hence Nan will be replaced with 'NA'

# %% [markdown]
# #### Convert Nominal Variables

# %%
# Convert all nan to 'NA' in Ordinal Variables
nominal_columns = [
        'Misc Feature',
        'Alley',
        'Garage Type',
        'Mas Vnr Type'
]

# Using list comprehension, for each column, replace nan with 'NA'
[train[x].replace(np.nan, 'NA_', inplace=True) for x in nominal_columns]
# Out:
# [None, None, None, None]

# %% [markdown]
# **Remarks**
#
# * As all the missing values in the ordinal variables can be replaced by 'NA', we used a list comprehension to iterate through the columns to replace the Nan

# %% [markdown]
# ### Continuous Variables
#
# 1. Lot Frontage
# 2. Mas Vnr Area

# %%
# Missing values for Lot Frontage
train.loc[
    train['Lot Frontage'].isnull(),
    ['Lot Frontage','Lot Area','Lot Shape','Lot Config']
]
# Out:
#       Lot Frontage  Lot Area Lot Shape Lot Config
# 0              NaN     13517       IR1    CulDSac
# 7              NaN     12160       IR1     Inside
# 8              NaN     15783       Reg     Inside
# 23             NaN      7980       IR1     Inside
# 27             NaN     11700       IR1     Inside
# ...            ...       ...       ...        ...
# 2016           NaN      7791       IR1     Inside
# 2022           NaN     16381       IR1     Inside
# 2028           NaN     20781       IR2    CulDSac
# 2031           NaN     12537       IR1    CulDSac
# 2047           NaN     12342       IR1     Inside
#
# [330 rows x 4 columns]

# %% [markdown]
# **Remarks**
#
# there are 330 missing values for 'Lot Frontage' which we would like to impute some values to as giving it a 0.0 will make this feature redundant to our model due to its errors.
#
# 'Lot Frontage' is the linear feet of street connected to the property, as such, lets take a look at the 'Neighborhood' feature and see if we can deduce any information from  here

# %% [markdown]
# #### Is there any relationship between the Neighborhood and Lot Frontage feature?

# %%
# Create dataframe with only 'Neighborhood' & 'Lot Frontage' features, and rows
# that 'Lot Frontage' have no missing values

df = train.loc[
    train['Lot Frontage'].notnull(),
    ['Lot Frontage','Neighborhood']
]

#Plot a boxplot to show the relationship of 'Neighborhood' & 'Lot Frontage'
plt.figure(figsize=(16,10))
sns.boxplot(
    data = df,
    y = 'Neighborhood',
    x = 'Lot Frontage'
)
plt.title('Neighborhood vs Lot Frontage');

# %% [markdown]
# There are 2 big outliers under NAmes and Edwards, but we'll put that aside for now, and determine if there is any relationship between 'Neighborhood' & 'Lot Frontage'. There seems to be a independant average for 'Lot Frontage' for each neighbourhood. Hence, we will input the mean 'Lot Frontage' for each Neighborhood into the missing values

# %%
# Check the mean of each neighborhood
train.groupby('Neighborhood')['Lot Frontage'].mean()
# Out:
# Neighborhood
# Blmngtn    47.250000
# Blueste    27.666667
# BrDale     21.315789
# BrkSide    56.357143
# ClearCr    92.500000
# CollgCr    70.753247
# Crawfor    69.272727
# Edwards    66.930233
# Gilbert    72.025641
# Greens     40.000000
# GrnHill          NaN
# IDOTRR     61.890625
# Landmrk          NaN
# MeadowV    26.809524
# Mitchel    75.476923
# NAmes      75.192453
# NPkVill    27.625000
# NWAmes     80.965517
# NoRidge    88.305556
# NridgHt    86.294118
# OldTown    62.802548
# SWISU      58.387097
# Sawyer     72.774648
# SawyerW    70.493333
# Somerst    63.982906
# StoneBr    60.058824
# Timber     78.594595
# Veenker    67.846154
# Name: Lot Frontage, dtype: float64

# %% [markdown]
#  The properties of the neighborhood of Landmrk & GrnHill, their lot frontage is all missing values, hence we'll assign them 0.0

# %%
# Locate houses in the Landmrk & GrnHill neighborhood and assign 0.0
train.loc[
    train['Neighborhood'].isin(['Landmrk','GrnHill']),
    ['Lot Frontage']
] = float()

# %%
# Function to impute the mean lot frontage of each neighborhood for each missing value
def lot_frontage_impute(row):
    if np.isnan(row['Lot Frontage']):
        neighborhood = row['Neighborhood']
        lot_frontage_mean = train[train['Neighborhood'] == neighborhood]['Lot Frontage'].mean()
        row['Lot Frontage'] = lot_frontage_mean
    return row

train.apply(lot_frontage_impute, axis=1)
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL     72.774648     13517   Pave
# 1      544  531379050           60        RL     43.000000     11492   Pave
# 2      153  535304180           20        RL     68.000000      7922   Pave
# 3      318  916386060           60        RL     73.000000      9802   Pave
# 4      255  906425045           50        RL     82.000000     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL     79.000000     11449   Pave
# 2047   785  905377130           30        RL     66.930233     12342   Pave
# 2048   916  909253010           50        RL     57.000000      7558   Pave
# 2049   639  535179160           20        RL     80.000000     10400   Pave
# 2050    10  527162130           60        RL     60.000000      7500   Pave
#
# ...

# %%
# Missing values for Mas Vnr Area
train.loc[
    train['Mas Vnr Area'].isnull(),
    ['Mas Vnr Area','Mas Vnr Type']
]
# Out:
#       Mas Vnr Area Mas Vnr Type
# 22             NaN          NA_
# 41             NaN          NA_
# 86             NaN          NA_
# 212            NaN          NA_
# 276            NaN          NA_
# 338            NaN          NA_
# 431            NaN          NA_
# 451            NaN          NA_
# 591            NaN          NA_
# 844            NaN          NA_
# 913            NaN          NA_
# 939            NaN          NA_
# 1025           NaN          NA_
# 1244           NaN          NA_
# 1306           NaN          NA_
# 1430           NaN          NA_
# 1434           NaN          NA_
# 1606           NaN          NA_
# 1699           NaN          NA_
# 1815           NaN          NA_
# 1820           NaN          NA_
# 1941           NaN          NA_

# %% [markdown]
# #### Convert missing continuous values

# %%
train['Mas Vnr Area'] = train['Mas Vnr Area'].fillna(float())
train['Lot Frontage'] = train['Lot Frontage'].fillna(float())

# %% [markdown]
# **Remarks**
#
# * As all the missing values in the continuos variables can be replaced by 0.0, we used a list comprehension to iterate through the columns to replace the Nan

# %% [markdown]
# ### Discrete Variables

# %%
# Check the unique values
print(train['Garage Yr Blt'].unique())

# Missing values for Garage Yr Blt
train.loc[
    train['Garage Yr Blt'].isnull(),
    ['Garage Yr Blt','Garage Type','Garage Finish','Garage Cars','Garage Area','Garage Qual','Garage Cond']
]
# Out:
# [1976. 1997. 1953. 2007. 1957. 1966. 2005. 1959. 1952. 1969. 1971. 1900.
#  2000. 2004. 1916. 1963. 1977. 2009. 1968. 1992. 1955. 1961. 1973. 1937.
#    nan 2003. 1981. 1931. 1995. 1958. 1965. 2006. 1978. 1954. 1935. 1951.
#  1996. 1999. 1920. 1930. 1924. 1960. 1949. 1986. 1956. 1994. 1979. 1964.
#  2001. 1972. 1939. 1962. 1927. 1948. 1967. 1993. 2010. 1915. 1987. 1970.
#  1988. 1982. 1941. 1984. 1942. 1950. 2002. 1975. 2008. 1974. 1998. 1918.
#  1938. 1985. 1923. 1980. 1991. 1946. 1940. 1990. 1896. 1983. 1914. 1945.
#  1921. 1925. 1926. 1936. 1932. 1947. 1929. 1910. 1917. 1922. 1934. 1989.
#  1928. 2207. 1933. 1895. 1919.]
#       Garage Yr Blt Garage Type Garage Finish  Garage Cars  Garage Area  \
# 28              NaN         NA_           NA_          0.0          0.0
# 53              NaN         NA_           NA_          0.0          0.0
# 65              NaN         NA_           NA_          0.0          0.0
# ...

# %% [markdown]
# - **Garage Yr Blt**
#     - Its deduced that the missing values represents there is no garage

# %% [markdown]
# #### Impute Missing Discrete Variables

# %% [markdown]
# * It would be a Nan

# %%
# create dataframe of 2 columns that excludes rows with missing values in 'Garage Yr Blt' column
df = train.loc[
    (train['Garage Yr Blt'].notnull()) & (train['Garage Yr Blt'] != 2207),
    ['Garage Yr Blt','Year Built']
]

#see if there is a close relationship between these 2 variables using corr
sns.regplot(
    x = 'Year Built',
    y = 'Garage Yr Blt',
    data = df
);

# %% [markdown]
# **Remarks**
#
# * The scatterplot shows most variables form a straight line of x=y. This is because for most houses, the year the house was built was the same year the garage was built.
# * We can observe that for most of the other variables that do not form the straight line, the garage is built after the year its built
# * Was initially considering to use a single regression imputation to predict missing values. However, it can be seen that we might be more accurate using deductive imputation, that the missing values in 'Garage Yr Blt' should be same as 'Year Built'

# %%
# Impute the missing values with its 'Year Built'

train['Garage Yr Blt'] = train['Garage Yr Blt'].fillna(train['Year Built'])

# %% [markdown]
# ### Others

# %%
# Missing Values for Bsmt Half Bath/Bsmt Full Bath/Garage Area/Total Bsmt SF/Bsmt Unf SF/BsmtFin SF 2/BsmtFin SF 1/Garage Cars
train.loc[
    (train['Bsmt Half Bath'].isnull()) | 
    (train['Bsmt Full Bath'].isnull()) | 
    (train['Garage Area'].isnull()) |
    (train['Total Bsmt SF'].isnull()) |
    (train['Bsmt Unf SF'].isnull()) |
    (train['BsmtFin SF 2'].isnull()) |
    (train['BsmtFin SF 1'].isnull()) |
    (train['Garage Cars'].isnull()),
    :
]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 616   1498  908154080           20        RL         123.0     47007   Pave
# 1327  1342  903230120           20        RM          99.0      5940   Pave
# 1712  2237  910201180           70        RM          50.0      9060   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 616    NA_       IR1          Lvl    AllPub     Inside        Gtl
# 1327   NA_       IR1          Lvl    AllPub        FR3        Gtl
# 1712   NA_       Reg          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 616       Edwards        Norm        Norm      1Fam      1Story             5
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
# 1712       IDOTRR        Norm        Norm      1Fam      2Story             5
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# ...

# %% [markdown]
# **Remarks**
# - For all the missing values in the above columns, its represented by these 3 rows
# - index 616 & 1327 both have 'Bsmt Full Bath' & 'Bsmt Half Bath' missing values
# - index 1712 has 'Garage' missing values, although they have 'Garage Type' listed
# - Decided to drop these 3 rows as their missing values will impact the model

# %%
# Drop rows with Index (616, 1327, 1712)
train.drop(
    index= [616, 1327, 1712], 
    axis = 0,
    inplace = True
)

# %%
#Check if there are still missing values
train.isnull(
).sum(
).sort_values(
    ascending = False
)
# Out:
# Id              0
# Heating QC      0
# Garage Type     0
# Fireplace Qu    0
# Fireplaces      0
#                ..
# Mas Vnr Type    0
# Exterior 2nd    0
# Exterior 1st    0
# Roof Matl       0
# SalePrice       0
# Length: 81, dtype: int64

# %% [markdown]
# There are no more missing values in the train dataset

# %% [markdown]
# ### Missing values in test dataset
#
# This section is for dealing with missing values in the test dataset.

# %%
test.shape
# Out:
# (879, 80)

# %%
test.isnull().sum().sort_values(ascending=False)[:20]
# Out:
# Pool QC           875
# Misc Feature      838
# Alley             821
# Fence             707
# Fireplace Qu      422
# Lot Frontage      160
# Garage Yr Blt      45
# Garage Finish      45
# Garage Qual        45
# Garage Cond        45
# Garage Type        44
# BsmtFin Type 1     25
# Bsmt Qual          25
# Bsmt Cond          25
# Bsmt Exposure      25
# BsmtFin Type 2     25
# Electrical          1
# Mas Vnr Type        1
# Mas Vnr Area        1
# Kitchen AbvGr       0
# dtype: int64

# %% [markdown]
# #### Missing value in Electrical

# %%
# Show row with Electrical missing value
test[test['Electrical'].isnull()]
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 635  1578  916386080           80        RL          73.0      9735   Pave
#
#     Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 635   NaN       Reg          Lvl    AllPub     Inside        Gtl       Timber
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 635        Norm        Norm      1Fam        SLvl             5             5
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 635        2006            2007      Gable   CompShg      VinylSd
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 635      VinylSd         None           0.0         TA         TA      PConc
#
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 635        Gd        TA            No            Unf             0
#
# ...

# %% [markdown]
# There is one house with a missing value in the Electrical feature. We know from its 'Utilities' feature that this house has (AllPub = All public Utilities), which means it will have an Electrical. As the electrical depends on the type of housing, we will check 'Ms SubClass' against 'Electrical'.

# %%
# Scatterplot of Electrical vs MS Subclass
sns.scatterplot(
        data = test,
        y = 'Electrical',
        x = 'MS SubClass')
plt.title('Test Data: Electrical vs MS SubClass');

# %%
# Check the count of Electrical in MS SubClass
test.groupby(['MS SubClass','Electrical']).count()
# Out:
#                          Id  PID  MS Zoning  Lot Frontage  Lot Area  Street  \
# MS SubClass Electrical
# 20          FuseA        16   16         16            14        16      16
#             FuseF         2    2          2             2         2       2
#             SBrkr       291  291        291           239       291     291
# 30          FuseA         7    7          7             7         7       7
#             FuseF         5    5          5             4         5       5
#             SBrkr        26   26         26            23        26      26
# 40          SBrkr         2    2          2             1         2       2
# 45          FuseA         2    2          2             2         2       2
#             SBrkr         5    5          5             5         5       5
# 50          FuseA        10   10         10            10        10      10
#             FuseF         5    5          5             4         5       5
# ...

# %% [markdown]
# We can see for 'MS SubClass' = 80, there are only 2 type of 'Electrical'
# - SBrkr = 30 houses
# - Fuse A = 1 house
#
# Based on most houses using SBrkr, we will impute that to the missing value.

# %%
# Impute the missing value with 'SBrkr'
test['Electrical'] = test['Electrical'].fillna('SBrkr')

# %% [markdown]
# #### Clean missing values

# %%
# Create a list of categorical columns with missing values
categorical_columns = [
        'Pool QC',
        'Misc Feature',
        'Alley',
        'Fence',
        'Fireplace Qu',
        'Garage Finish',
        'Garage Qual',
        'Garage Cond',
        'Garage Type',
        'BsmtFin Type 1',
        'Bsmt Qual',
        'Bsmt Cond',
        'Bsmt Exposure',
        'BsmtFin Type 2',
        'Mas Vnr Type',      
]

# Using list comprehension, for each column, replace nan with 'NA_'
[test[x].replace(np.nan, 'NA_', inplace=True) for x in categorical_columns]

#

# Create a list of categorical columns with missing values
numerical_columns = [
        'Lot Frontage',
        'Mas Vnr Area'
]

# Using list comprehension, for each column, replace nan with float()
[test[x].replace(np.nan, float(), inplace=True) for x in numerical_columns]


# Impute the missing values with its 'Year Built'
test['Garage Yr Blt'] = test['Garage Yr Blt'].fillna(test['Year Built'])

# %% [markdown]
# ### Rename the Feature Names
# Currently the column names have spaces and uppercase letters. For uniformity and to avoid confusion, we will use [snake_case](https://en.wikipedia.org/wiki/Snake_case) for all the column names

# %%
# Index through each column name and lowercase and replace each space with an underscore
train.columns = train.columns.str.lower().str.replace(' ','_')
test.columns = test.columns.str.lower().str.replace(' ','_')

# %%
train['alley'] = train['alley'].astype(object)

# %% [markdown]
# ### Export train data to folder

# %%
# Write train & test dataframe to a csv file and store in folder
train.to_csv('./datasets/clean_train.csv', index=False)
test.to_csv('./datasets/clean_test.csv', index=False)

# %%
print(test.shape)
print(train.shape)
print(test.isnull().sum().sort_values())
# Out:
# (879, 80)
# (2048, 81)
# id                0
# fireplaces        0
# functional        0
# totrms_abvgrd     0
# kitchen_qual      0
#                  ..
# roof_matl         0
# roof_style        0
# year_remod/add    0
# yr_sold           0
# sale_type         0
# Length: 80, dtype: int64
